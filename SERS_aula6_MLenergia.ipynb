# %% [markdown]
# <a href="https://colab.research.google.com/github/lanaozeki08-jpg/SERS_aula06_MLenergy/blob/main/SERS_aula6_MLenergia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #exercício
#
# treinar um modelo preditivo de classificação da estabilidade de uma rede elétrica
#
# fonte: https://archive.ics.uci.edu/datasets/?search=Electrical+Grid+Stability+Simulated+Data+

# %% [markdown]
# ###preparação do ambiente

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# machie learning
# algoritmos do sklearn para classificação
from sklearn.linear_model import LogisticRegression #numoro
from sklearn.tree import DecisionTreeClassifier #classes (a ou b)

# separação os dados de treino e teste
from sklearn.model_selection import train_test_split
# X_train, X_test, Y_train, Y_test: X entrada (características do modelo, feature) e Y saída (target)

# métricas para classificação
from sklearn.metrics import accuracy_score # acurácia
from sklearn.metrics import confusion_matrix # identificação de onde o modelo errou
from sklearn.metrics import classification_report # resumo de métricas
